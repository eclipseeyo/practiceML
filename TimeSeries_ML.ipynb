# %% [markdown]
# <a href="https://colab.research.google.com/github/eclipseeyo/practiceML/blob/main/TimeSeries_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Машинное обучение для временных рядов

# %% [markdown]
# План семинара:
#
# 1. Обучение моделей
# 2. ETNA для построения прогнозов
# 3. Учет экзогенных факторов

# %%
# !pip install catboost -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 MB 7.0 MB/s eta 0:00:00

# %%
import warnings
warnings.filterwarnings('ignore')

from catboost import CatBoostRegressor

import matplotlib.dates as mdates
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.metrics import mean_squared_error, mean_absolute_error
from tqdm.notebook import tqdm

# %config InlineBackend.figure_format = 'svg'
from pylab import rcParams
rcParams['figure.figsize'] = 7, 5

# %% [markdown]
# ### Предобработка временного ряда  <a name="preprocess">

# %% [markdown]
# Возьмем датасет, в котором будет присутвовать переменная, изменяющася во времени. Давайте сегодня попробуем поработать с набором данных по среднесуточной дневной температуре в городе Дели, собранном за несколько лет. Подробнее почитать про датасет можно на [Kaggle](https://www.kaggle.com/sumanthvrao/daily-climate-time-series-data)
#
# Датасет сразу разбит на две части - train и test, но будем использовать для обучения и валидации моделей только train, оставив test как отложенную выборку для проверки качества.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/aiedu-courses/stepik_applied_tasks/main/datasets/DailyDelhiClimateTrain.csv')

print(f"Дни с {min(df.date)} по {max(df.date)}, всего {df.date.nunique()} дней.")
df.head()
# Out:
# Дни с 2013-01-01 по 2016-12-31, всего 1461 дней.
#          date   meantemp   humidity  wind_speed  meanpressure
# 0  2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 1  2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2  2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 3  2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 4  2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %%
df['date'] = pd.to_datetime(df['date'], format = '%Y-%m-%d')

df = df[['date','meantemp']].set_index('date')

df.head()
# Out:
#              meantemp
# date
# 2013-01-01  10.000000
# 2013-01-02   7.400000
# 2013-01-03   7.166667
# 2013-01-04   8.666667
# 2013-01-05   6.000000

# %%
df.plot()
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# ### Генерация признаков <a name="features">

# %% [markdown]
# Основные подходы по генерации признаков:
#
# * лаговые признаки (lags) - значения ряда в предыдущие моменты времени
#
# * агрегации (среднее значение ряда по часу, дню, месяцу и так далее; медиана, дисперсия и так далее)

# %% [markdown]
# Напишем функцию, которая возвращает словарь, где ключами являются уникальные категории признака cat_feature, а значениями - средние по real_feature.

# %%
def code_mean(data, cat_feature, real_feature):
    return dict(data.groupby(cat_feature)[real_feature].mean())

# %%
df["month"] = df.index.month

d = code_mean(df, "month", "meantemp")

plt.plot(d.keys(), d.values())

# %% [markdown]
# Можно это удобно обернуть в функцию и заменить исходные признаки на их среднее как один из вариантов препроцессинга, а также - добавить значения целевой переменной с разной длинной временного лага.
#
# В функции мы:
#
# 1) Разбиваем данные на тренировочную и тестовую части
#
# 2) Генерируем лаговые признаки
#
# 3) Генерируем агрегированные признаки

# %%
def preprocess_data(data, lag_start=5, lag_end=20, test_size=0.15):

    data = pd.DataFrame(data.copy())

    # считаем индекс в датафрейме, после которого начинается тестовый отрезок
    test_index = int(len(data) * (1 - test_size))

    # добавляем лаги исходного ряда в качестве признаков
    for i in range(lag_start, lag_end):
        data[f"lag_{i}"] = data.meantemp.shift(i)

    data["weekday"] = data.index.weekday
#    data["week"] = data.index.week
    data["month"] = data.index.month
    data["year"] = data.index.year

    # считаем средние только по тренировочной части, чтобы избежать лика (data leak)
    data["weekday_average"] = list(map(code_mean(data[:test_index], "weekday", "meantemp").get, data.weekday))
#    data["week_average"] = list(map(code_mean(data[:test_index], "week", "meantemp").get, data.week))
    data["month_average"] = list(map(code_mean(data[:test_index], "month", "meantemp").get, data.month))
    data["year_average"] = list(map(code_mean(data[:test_index], "year", "meantemp").get, data.year))

    # выкидываем закодированные средними признаки
    data.drop(["weekday", 'month', 'year'], axis=1, inplace=True)

    data = data.dropna()
    data = data.reset_index(drop=True)

    # разбиваем весь датасет на тренировочную и тестовую выборку
    X_train = data.loc[:test_index].drop(["meantemp"], axis=1)
    y_train = data.loc[:test_index]["meantemp"]
    X_test = data.loc[test_index:].drop(["meantemp"], axis=1)
    y_test = data.loc[test_index:]["meantemp"]

    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = preprocess_data(df, test_size=0.3, lag_start=3, lag_end=10)

X_train.head()
# Out:
#        lag_3      lag_4      lag_5     lag_6     lag_7     lag_8      lag_9  \
# 0   7.000000   7.000000   6.000000  8.666667  7.166667  7.400000  10.000000
# 1   8.857143   7.000000   7.000000  6.000000  8.666667  7.166667   7.400000
# 2  14.000000   8.857143   7.000000  7.000000  6.000000  8.666667   7.166667
# 3  11.000000  14.000000   8.857143  7.000000  7.000000  6.000000   8.666667
# 4  15.714286  11.000000  14.000000  8.857143  7.000000  7.000000   6.000000
#
#    weekday_average  month_average  year_average
# 0        25.440460      12.738377     24.791494
# 1        25.372054      12.738377     24.791494
# 2        25.331414      12.738377     24.791494
# 3        25.202210      12.738377     24.791494
# 4        25.499234      12.738377     24.791494

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train, y_train)

preds = lr.predict(X_test)

plt.figure(figsize=(10, 5))
plt.plot(preds, "r", label="prediction")
plt.plot(y_test.values, label="actual")
plt.grid(True)
plt.legend(loc="best")
plt.title(f"Linear regression\n Mean absolute error {mean_absolute_error(preds, y_test)} degrees");

# %%
coef_table = pd.DataFrame({'features' : list(X_train.columns), 'weights' : lr.coef_})

coef_table.sort_values(by='weights')
# Out:
#           features   weights
# 6            lag_9 -0.017693
# 4            lag_7 -0.008115
# 5            lag_8  0.016994
# 2            lag_5  0.027257
# 3            lag_6  0.038893
# 9     year_average  0.069241
# 1            lag_4  0.096807
# 0            lag_3  0.377216
# 8    month_average  0.459795
# 7  weekday_average  1.371299

# %% [markdown]
# ## DecisionTree

# %%
from sklearn.tree import DecisionTreeRegressor

dt = DecisionTreeRegressor()
dt.fit(X_train, y_train)
preds = dt.predict(X_test)

plt.figure(figsize=(10, 5))
plt.plot(preds, "r", label="prediction")
plt.plot(y_test.values, label="actual")
plt.grid(True)
plt.legend(loc="best")
plt.title(f"Linear regression\n Mean absolute error {mean_absolute_error(preds, y_test)} degrees");

# %% [markdown]
# ## RandomForest

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor()
rf.fit(X_train, y_train)
preds = rf.predict(X_test)

plt.figure(figsize=(10, 5))
plt.plot(preds, "r", label="prediction")
plt.plot(y_test.values, label="actual")
plt.grid(True)
plt.legend(loc="best")
plt.title(f"Linear regression\n Mean absolute error {mean_absolute_error(preds, y_test)} degrees");

# %% [markdown]
# ## CatBoost

# %%
cb = CatBoostRegressor(n_estimators=300)
cb.fit(X_train, y_train)
preds = cb.predict(X_test)

plt.figure(figsize=(10, 5))
plt.plot(preds, "r", label="prediction")
plt.plot(y_test.values, label="actual")
plt.grid(True)
plt.legend(loc="best")
plt.title(f"Linear regression\n Mean absolute error {mean_absolute_error(preds, y_test)} degrees");
# Out:
# Learning rate set to 0.109355
# 0:	learn: 6.6174733	total: 59.3ms	remaining: 17.7s
# 1:	learn: 6.0331380	total: 69.9ms	remaining: 10.4s
# 2:	learn: 5.5098821	total: 88ms	remaining: 8.71s
# 3:	learn: 5.0551155	total: 102ms	remaining: 7.55s
# 4:	learn: 4.6496495	total: 110ms	remaining: 6.5s
# 5:	learn: 4.2958289	total: 118ms	remaining: 5.76s
# 6:	learn: 3.9925983	total: 128ms	remaining: 5.34s
# 7:	learn: 3.7388168	total: 143ms	remaining: 5.21s
# 8:	learn: 3.4900130	total: 147ms	remaining: 4.74s
# 9:	learn: 3.2789233	total: 160ms	remaining: 4.65s
# 10:	learn: 3.1042190	total: 164ms	remaining: 4.32s
# 11:	learn: 2.9457228	total: 175ms	remaining: 4.21s
# 12:	learn: 2.8083740	total: 182ms	remaining: 4.02s
# 13:	learn: 2.6961076	total: 192ms	remaining: 3.93s
# 14:	learn: 2.6034971	total: 205ms	remaining: 3.89s
# 15:	learn: 2.5219267	total: 211ms	remaining: 3.74s
# 16:	learn: 2.4522084	total: 213ms	remaining: 3.54s
# 17:	learn: 2.3889236	total: 218ms	remaining: 3.42s
# 18:	learn: 2.3407885	total: 220ms	remaining: 3.26s
# 19:	learn: 2.2954340	total: 222ms	remaining: 3.11s
# 20:	learn: 2.2681148	total: 225ms	remaining: 2.99s
# 21:	learn: 2.2320889	total: 227ms	remaining: 2.87s
# 22:	learn: 2.2082581	total: 230ms	remaining: 2.77s
# 23:	learn: 2.1827697	total: 232ms	remaining: 2.67s
# 24:	learn: 2.1633836	total: 235ms	remaining: 2.58s
# 25:	learn: 2.1438116	total: 238ms	remaining: 2.5s
# 26:	learn: 2.1284259	total: 240ms	remaining: 2.43s
# 27:	learn: 2.1139227	total: 242ms	remaining: 2.35s
# 28:	learn: 2.1052790	total: 245ms	remaining: 2.29s
# 29:	learn: 2.0970051	total: 247ms	remaining: 2.22s
# 30:	learn: 2.0854230	total: 250ms	remaining: 2.17s
# 31:	learn: 2.0742654	total: 252ms	remaining: 2.11s
# 32:	learn: 2.0646070	total: 254ms	remaining: 2.06s
# 33:	learn: 2.0573706	total: 256ms	remaining: 2s
# 34:	learn: 2.0505533	total: 259ms	remaining: 1.96s
# 35:	learn: 2.0414431	total: 261ms	remaining: 1.91s
# 36:	learn: 2.0361219	total: 264ms	remaining: 1.88s
# 37:	learn: 2.0276954	total: 267ms	remaining: 1.84s
# 38:	learn: 2.0194612	total: 272ms	remaining: 1.82s
# 39:	learn: 2.0126636	total: 287ms	remaining: 1.87s
# 40:	learn: 2.0006230	total: 292ms	remaining: 1.84s
# 41:	learn: 1.9961873	total: 298ms	remaining: 1.83s
# 42:	learn: 1.9920786	total: 302ms	remaining: 1.8s
# 43:	learn: 1.9869226	total: 305ms	remaining: 1.77s
# 44:	learn: 1.9799845	total: 311ms	remaining: 1.76s
# 45:	learn: 1.9732166	total: 318ms	remaining: 1.75s
# 46:	learn: 1.9668227	total: 323ms	remaining: 1.74s
# 47:	learn: 1.9560356	total: 330ms	remaining: 1.73s
# 48:	learn: 1.9502194	total: 336ms	remaining: 1.72s
# 49:	learn: 1.9425876	total: 342ms	remaining: 1.71s
# 50:	learn: 1.9376814	total: 348ms	remaining: 1.7s
# 51:	learn: 1.9301508	total: 357ms	remaining: 1.7s
# 52:	learn: 1.9231784	total: 367ms	remaining: 1.71s
# 53:	learn: 1.9179500	total: 376ms	remaining: 1.71s
# 54:	learn: 1.9103758	total: 380ms	remaining: 1.69s
# 55:	learn: 1.9045984	total: 387ms	remaining: 1.69s
# 56:	learn: 1.9002489	total: 397ms	remaining: 1.69s
# 57:	learn: 1.8916936	total: 411ms	remaining: 1.71s
# 58:	learn: 1.8854619	total: 417ms	remaining: 1.7s
# 59:	learn: 1.8788525	total: 423ms	remaining: 1.69s
# 60:	learn: 1.8737291	total: 430ms	remaining: 1.68s
# 61:	learn: 1.8668889	total: 438ms	remaining: 1.68s
# 62:	learn: 1.8615474	total: 451ms	remaining: 1.7s
# 63:	learn: 1.8577508	total: 457ms	remaining: 1.69s
# 64:	learn: 1.8517238	total: 469ms	remaining: 1.7s
# 65:	learn: 1.8451174	total: 477ms	remaining: 1.69s
# 66:	learn: 1.8397327	total: 482ms	remaining: 1.67s
# 67:	learn: 1.8351474	total: 495ms	remaining: 1.69s
# 68:	learn: 1.8287865	total: 508ms	remaining: 1.7s
# 69:	learn: 1.8266190	total: 515ms	remaining: 1.69s
# 70:	learn: 1.8214528	total: 521ms	remaining: 1.68s
# 71:	learn: 1.8172398	total: 533ms	remaining: 1.69s
# 72:	learn: 1.8113293	total: 541ms	remaining: 1.68s
# 73:	learn: 1.8058894	total: 560ms	remaining: 1.71s
# 74:	learn: 1.8002317	total: 566ms	remaining: 1.7s
# 75:	learn: 1.7957522	total: 577ms	remaining: 1.7s
# 76:	learn: 1.7871967	total: 590ms	remaining: 1.71s
# 77:	learn: 1.7861521	total: 595ms	remaining: 1.69s
# 78:	learn: 1.7805119	total: 608ms	remaining: 1.7s
# 79:	learn: 1.7768254	total: 618ms	remaining: 1.7s
# 80:	learn: 1.7717688	total: 624ms	remaining: 1.69s
# 81:	learn: 1.7656520	total: 636ms	remaining: 1.69s
# 82:	learn: 1.7602362	total: 646ms	remaining: 1.69s
# 83:	learn: 1.7563980	total: 655ms	remaining: 1.69s
# 84:	learn: 1.7519523	total: 665ms	remaining: 1.68s
# 85:	learn: 1.7461555	total: 673ms	remaining: 1.68s
# 86:	learn: 1.7412318	total: 686ms	remaining: 1.68s
# 87:	learn: 1.7342667	total: 692ms	remaining: 1.67s
# 88:	learn: 1.7313567	total: 700ms	remaining: 1.66s
# 89:	learn: 1.7287961	total: 716ms	remaining: 1.67s
# 90:	learn: 1.7226032	total: 727ms	remaining: 1.67s
# 91:	learn: 1.7207661	total: 737ms	remaining: 1.67s
# 92:	learn: 1.7150114	total: 743ms	remaining: 1.65s
# 93:	learn: 1.7096521	total: 756ms	remaining: 1.66s
# 94:	learn: 1.7031488	total: 767ms	remaining: 1.66s
# 95:	learn: 1.6993029	total: 777ms	remaining: 1.65s
# 96:	learn: 1.6910477	total: 788ms	remaining: 1.65s
# 97:	learn: 1.6866122	total: 799ms	remaining: 1.65s
# 98:	learn: 1.6815839	total: 806ms	remaining: 1.64s
# 99:	learn: 1.6778644	total: 811ms	remaining: 1.62s
# 100:	learn: 1.6703879	total: 817ms	remaining: 1.61s
# 101:	learn: 1.6611345	total: 823ms	remaining: 1.6s
# 102:	learn: 1.6567880	total: 829ms	remaining: 1.59s
# 103:	learn: 1.6487379	total: 836ms	remaining: 1.57s
# 104:	learn: 1.6411436	total: 842ms	remaining: 1.56s
# 105:	learn: 1.6329067	total: 848ms	remaining: 1.55s
# 106:	learn: 1.6254575	total: 860ms	remaining: 1.55s
# 107:	learn: 1.6190439	total: 865ms	remaining: 1.54s
# 108:	learn: 1.6136814	total: 874ms	remaining: 1.53s
# 109:	learn: 1.6091930	total: 879ms	remaining: 1.52s
# 110:	learn: 1.6046588	total: 885ms	remaining: 1.51s
# 111:	learn: 1.6016058	total: 893ms	remaining: 1.5s
# 112:	learn: 1.5961835	total: 899ms	remaining: 1.49s
# 113:	learn: 1.5923150	total: 905ms	remaining: 1.48s
# 114:	learn: 1.5876812	total: 910ms	remaining: 1.46s
# 115:	learn: 1.5814846	total: 913ms	remaining: 1.45s
# 116:	learn: 1.5802534	total: 916ms	remaining: 1.43s
# 117:	learn: 1.5721602	total: 919ms	remaining: 1.42s
# 118:	learn: 1.5693736	total: 926ms	remaining: 1.41s
# 119:	learn: 1.5653358	total: 928ms	remaining: 1.39s
# 120:	learn: 1.5608381	total: 930ms	remaining: 1.38s
# 121:	learn: 1.5598755	total: 933ms	remaining: 1.36s
# 122:	learn: 1.5543941	total: 935ms	remaining: 1.34s
# 123:	learn: 1.5505757	total: 937ms	remaining: 1.33s
# 124:	learn: 1.5466084	total: 939ms	remaining: 1.31s
# 125:	learn: 1.5409422	total: 941ms	remaining: 1.3s
# 126:	learn: 1.5368650	total: 943ms	remaining: 1.28s
# 127:	learn: 1.5334058	total: 945ms	remaining: 1.27s
# 128:	learn: 1.5276591	total: 947ms	remaining: 1.25s
# 129:	learn: 1.5248491	total: 949ms	remaining: 1.24s
# 130:	learn: 1.5237217	total: 952ms	remaining: 1.23s
# 131:	learn: 1.5204835	total: 954ms	remaining: 1.21s
# 132:	learn: 1.5160535	total: 956ms	remaining: 1.2s
# 133:	learn: 1.5137636	total: 964ms	remaining: 1.19s
# 134:	learn: 1.5103672	total: 969ms	remaining: 1.18s
# 135:	learn: 1.5035888	total: 971ms	remaining: 1.17s
# 136:	learn: 1.5021670	total: 974ms	remaining: 1.16s
# 137:	learn: 1.5013921	total: 979ms	remaining: 1.15s
# 138:	learn: 1.4993541	total: 981ms	remaining: 1.14s
# 139:	learn: 1.4922249	total: 990ms	remaining: 1.13s
# 140:	learn: 1.4881353	total: 995ms	remaining: 1.12s
# 141:	learn: 1.4810355	total: 1s	remaining: 1.11s
# 142:	learn: 1.4769495	total: 1.01s	remaining: 1.1s
# 143:	learn: 1.4727947	total: 1.01s	remaining: 1.1s
# 144:	learn: 1.4664293	total: 1.02s	remaining: 1.09s
# 145:	learn: 1.4599349	total: 1.02s	remaining: 1.08s
# 146:	learn: 1.4572755	total: 1.03s	remaining: 1.07s
# 147:	learn: 1.4514543	total: 1.04s	remaining: 1.06s
# 148:	learn: 1.4453366	total: 1.05s	remaining: 1.06s
# 149:	learn: 1.4424848	total: 1.05s	remaining: 1.05s
# 150:	learn: 1.4398941	total: 1.06s	remaining: 1.04s
# 151:	learn: 1.4390879	total: 1.06s	remaining: 1.03s
# 152:	learn: 1.4338548	total: 1.07s	remaining: 1.03s
# 153:	learn: 1.4317603	total: 1.07s	remaining: 1.02s
# 154:	learn: 1.4313766	total: 1.08s	remaining: 1.01s
# 155:	learn: 1.4290589	total: 1.1s	remaining: 1.02s
# 156:	learn: 1.4233256	total: 1.11s	remaining: 1.01s
# 157:	learn: 1.4177584	total: 1.12s	remaining: 1s
# 158:	learn: 1.4120270	total: 1.13s	remaining: 1s
# 159:	learn: 1.4087657	total: 1.14s	remaining: 997ms
# 160:	learn: 1.4029777	total: 1.15s	remaining: 992ms
# 161:	learn: 1.4014121	total: 1.15s	remaining: 983ms
# 162:	learn: 1.3952681	total: 1.16s	remaining: 977ms
# 163:	learn: 1.3911193	total: 1.17s	remaining: 974ms
# 164:	learn: 1.3875693	total: 1.18s	remaining: 969ms
# 165:	learn: 1.3855002	total: 1.19s	remaining: 959ms
# 166:	learn: 1.3815039	total: 1.2s	remaining: 957ms
# 167:	learn: 1.3766102	total: 1.21s	remaining: 948ms
# 168:	learn: 1.3728625	total: 1.21s	remaining: 940ms
# 169:	learn: 1.3691271	total: 1.22s	remaining: 932ms
# 170:	learn: 1.3656117	total: 1.22s	remaining: 923ms
# 171:	learn: 1.3614527	total: 1.23s	remaining: 916ms
# 172:	learn: 1.3584641	total: 1.24s	remaining: 907ms
# 173:	learn: 1.3547781	total: 1.24s	remaining: 899ms
# 174:	learn: 1.3533726	total: 1.25s	remaining: 891ms
# 175:	learn: 1.3495405	total: 1.25s	remaining: 884ms
# 176:	learn: 1.3457711	total: 1.26s	remaining: 875ms
# 177:	learn: 1.3426445	total: 1.26s	remaining: 867ms
# 178:	learn: 1.3404621	total: 1.27s	remaining: 860ms
# 179:	learn: 1.3378252	total: 1.28s	remaining: 852ms
# 180:	learn: 1.3349787	total: 1.3s	remaining: 852ms
# 181:	learn: 1.3319033	total: 1.31s	remaining: 848ms
# 182:	learn: 1.3276810	total: 1.31s	remaining: 840ms
# 183:	learn: 1.3257586	total: 1.32s	remaining: 833ms
# 184:	learn: 1.3233708	total: 1.33s	remaining: 830ms
# 185:	learn: 1.3198399	total: 1.34s	remaining: 822ms
# 186:	learn: 1.3160326	total: 1.35s	remaining: 817ms
# 187:	learn: 1.3131461	total: 1.36s	remaining: 810ms
# 188:	learn: 1.3119431	total: 1.37s	remaining: 804ms
# 189:	learn: 1.3082054	total: 1.38s	remaining: 798ms
# 190:	learn: 1.3062761	total: 1.39s	remaining: 793ms
# 191:	learn: 1.3044616	total: 1.4s	remaining: 789ms
# 192:	learn: 1.3025335	total: 1.41s	remaining: 781ms
# 193:	learn: 1.2971622	total: 1.41s	remaining: 772ms
# 194:	learn: 1.2962018	total: 1.42s	remaining: 767ms
# 195:	learn: 1.2902223	total: 1.43s	remaining: 759ms
# 196:	learn: 1.2881239	total: 1.44s	remaining: 751ms
# 197:	learn: 1.2846942	total: 1.45s	remaining: 746ms
# 198:	learn: 1.2791403	total: 1.45s	remaining: 738ms
# 199:	learn: 1.2755292	total: 1.46s	remaining: 730ms
# 200:	learn: 1.2731234	total: 1.47s	remaining: 722ms
# 201:	learn: 1.2696355	total: 1.48s	remaining: 716ms
# 202:	learn: 1.2694944	total: 1.48s	remaining: 708ms
# 203:	learn: 1.2665347	total: 1.49s	remaining: 700ms
# 204:	learn: 1.2623965	total: 1.5s	remaining: 694ms
# 205:	learn: 1.2609479	total: 1.5s	remaining: 686ms
# 206:	learn: 1.2594775	total: 1.51s	remaining: 678ms
# 207:	learn: 1.2571877	total: 1.51s	remaining: 670ms
# 208:	learn: 1.2540505	total: 1.52s	remaining: 661ms
# 209:	learn: 1.2505352	total: 1.52s	remaining: 654ms
# 210:	learn: 1.2466669	total: 1.53s	remaining: 646ms
# 211:	learn: 1.2452478	total: 1.54s	remaining: 638ms
# 212:	learn: 1.2413647	total: 1.55s	remaining: 635ms
# 213:	learn: 1.2408665	total: 1.56s	remaining: 627ms
# 214:	learn: 1.2395604	total: 1.57s	remaining: 619ms
# 215:	learn: 1.2358500	total: 1.57s	remaining: 612ms
# 216:	learn: 1.2315358	total: 1.58s	remaining: 604ms
# 217:	learn: 1.2300857	total: 1.59s	remaining: 597ms
# 218:	learn: 1.2265127	total: 1.59s	remaining: 588ms
# 219:	learn: 1.2251726	total: 1.6s	remaining: 581ms
# 220:	learn: 1.2227524	total: 1.6s	remaining: 573ms
# 221:	learn: 1.2167510	total: 1.61s	remaining: 565ms
# 222:	learn: 1.2124017	total: 1.61s	remaining: 557ms
# 223:	learn: 1.2075557	total: 1.62s	remaining: 549ms
# 224:	learn: 1.2034580	total: 1.62s	remaining: 541ms
# 225:	learn: 1.1996799	total: 1.63s	remaining: 533ms
# 226:	learn: 1.1980503	total: 1.63s	remaining: 525ms
# 227:	learn: 1.1963628	total: 1.64s	remaining: 517ms
# 228:	learn: 1.1959267	total: 1.64s	remaining: 510ms
# 229:	learn: 1.1914126	total: 1.65s	remaining: 502ms
# 230:	learn: 1.1888439	total: 1.66s	remaining: 495ms
# 231:	learn: 1.1862668	total: 1.66s	remaining: 488ms
# 232:	learn: 1.1825538	total: 1.67s	remaining: 480ms
# 233:	learn: 1.1786358	total: 1.68s	remaining: 474ms
# 234:	learn: 1.1741492	total: 1.69s	remaining: 467ms
# 235:	learn: 1.1737203	total: 1.69s	remaining: 459ms
# 236:	learn: 1.1692853	total: 1.7s	remaining: 452ms
# 237:	learn: 1.1675533	total: 1.71s	remaining: 445ms
# 238:	learn: 1.1665782	total: 1.72s	remaining: 438ms
# 239:	learn: 1.1636609	total: 1.72s	remaining: 430ms
# 240:	learn: 1.1591726	total: 1.73s	remaining: 423ms
# 241:	learn: 1.1575297	total: 1.73s	remaining: 415ms
# 242:	learn: 1.1522080	total: 1.74s	remaining: 408ms
# 243:	learn: 1.1511787	total: 1.75s	remaining: 401ms
# 244:	learn: 1.1488885	total: 1.75s	remaining: 393ms
# 245:	learn: 1.1449843	total: 1.77s	remaining: 388ms
# 246:	learn: 1.1438843	total: 1.77s	remaining: 380ms
# 247:	learn: 1.1412944	total: 1.78s	remaining: 373ms
# 248:	learn: 1.1373836	total: 1.78s	remaining: 365ms
# 249:	learn: 1.1351627	total: 1.79s	remaining: 358ms
# 250:	learn: 1.1327064	total: 1.79s	remaining: 351ms
# 251:	learn: 1.1299698	total: 1.8s	remaining: 343ms
# 252:	learn: 1.1297900	total: 1.81s	remaining: 336ms
# 253:	learn: 1.1262481	total: 1.81s	remaining: 328ms
# 254:	learn: 1.1250276	total: 1.82s	remaining: 320ms
# 255:	learn: 1.1216941	total: 1.82s	remaining: 313ms
# 256:	learn: 1.1204628	total: 1.83s	remaining: 306ms
# 257:	learn: 1.1202920	total: 1.83s	remaining: 299ms
# 258:	learn: 1.1181233	total: 1.84s	remaining: 292ms
# 259:	learn: 1.1152027	total: 1.85s	remaining: 284ms
# 260:	learn: 1.1129970	total: 1.85s	remaining: 277ms
# 261:	learn: 1.1127770	total: 1.86s	remaining: 270ms
# 262:	learn: 1.1122859	total: 1.87s	remaining: 263ms
# 263:	learn: 1.1073727	total: 1.87s	remaining: 256ms
# 264:	learn: 1.1038707	total: 1.88s	remaining: 249ms
# 265:	learn: 1.1009054	total: 1.89s	remaining: 241ms
# 266:	learn: 1.0966817	total: 1.9s	remaining: 235ms
# 267:	learn: 1.0954497	total: 1.91s	remaining: 228ms
# 268:	learn: 1.0916606	total: 1.91s	remaining: 221ms
# 269:	learn: 1.0902595	total: 1.92s	remaining: 213ms
# 270:	learn: 1.0865891	total: 1.92s	remaining: 206ms
# 271:	learn: 1.0826036	total: 1.93s	remaining: 199ms
# 272:	learn: 1.0808631	total: 1.94s	remaining: 192ms
# 273:	learn: 1.0798017	total: 1.94s	remaining: 184ms
# 274:	learn: 1.0788519	total: 1.95s	remaining: 177ms
# 275:	learn: 1.0773796	total: 1.95s	remaining: 170ms
# 276:	learn: 1.0758403	total: 1.96s	remaining: 163ms
# 277:	learn: 1.0735979	total: 1.97s	remaining: 156ms
# 278:	learn: 1.0708446	total: 1.97s	remaining: 149ms
# 279:	learn: 1.0687836	total: 1.98s	remaining: 141ms
# 280:	learn: 1.0643623	total: 1.99s	remaining: 134ms
# 281:	learn: 1.0617179	total: 1.99s	remaining: 127ms
# 282:	learn: 1.0597358	total: 2s	remaining: 120ms
# 283:	learn: 1.0571381	total: 2.01s	remaining: 113ms
# 284:	learn: 1.0538760	total: 2.01s	remaining: 106ms
# 285:	learn: 1.0517808	total: 2.02s	remaining: 98.8ms
# 286:	learn: 1.0493541	total: 2.02s	remaining: 91.7ms
# 287:	learn: 1.0458287	total: 2.03s	remaining: 84.5ms
# 288:	learn: 1.0429685	total: 2.03s	remaining: 77.4ms
# 289:	learn: 1.0427092	total: 2.04s	remaining: 70.4ms
# 290:	learn: 1.0396657	total: 2.05s	remaining: 63.5ms
# 291:	learn: 1.0388659	total: 2.06s	remaining: 56.4ms
# 292:	learn: 1.0368117	total: 2.07s	remaining: 49.5ms
# 293:	learn: 1.0354106	total: 2.08s	remaining: 42.4ms
# 294:	learn: 1.0341097	total: 2.09s	remaining: 35.4ms
# 295:	learn: 1.0337338	total: 2.1s	remaining: 28.3ms
# 296:	learn: 1.0320090	total: 2.11s	remaining: 21.3ms
# 297:	learn: 1.0307163	total: 2.12s	remaining: 14.2ms
# 298:	learn: 1.0275093	total: 2.12s	remaining: 7.09ms
# 299:	learn: 1.0258072	total: 2.13s	remaining: 0us

# %%
coef_table = pd.DataFrame({'features' : list(X_train.columns), 'weights' : cb.feature_importances_})

coef_table.sort_values(by='weights')
# Out:
#           features    weights
# 7  weekday_average   1.881659
# 9     year_average   2.808518
# 5            lag_8   5.971401
# 6            lag_9   7.934825
# 2            lag_5   8.789507
# 3            lag_6  10.718071
# 4            lag_7  11.321736
# 1            lag_4  12.442181
# 0            lag_3  17.748921
# 8    month_average  20.383182

# %% [markdown]
# ## Библиотеки для работы с временными рядами
#
# Для работы с временными рядами существует несколько хороших библиотек. Мы немного посмотрим на библиотеку ETNA, но есть и другие.
#
# Среди них: библиотека от Facebook [Prophet](https://github.com/facebook/prophet), [tsfresh](https://github.com/blue-yonder/tsfresh), [darts](https://github.com/unit8co/darts) и другие (можно посмотреть на github).

# %% [markdown]
# Источники:
#
# 1. Пост на Хабре от ODS https://habr.com/ru/company/ods/blog/327242/
# 2. Онлайн-учебник курса по продвинутому статистическому прогнозированию университета Duke  https://people.duke.edu/~rnau/411home.htm

# %% [markdown]
# # ETNA (от Тинькофф)
#
# Первая общедоступная версия библиотеки появилась в сентябре 2021 г.

# %%
# !pip install etna -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 422.2/422.2 kB 4.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 354.1/354.1 kB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 6.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 27.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.2/57.2 kB 6.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 5.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 23.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 43.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 47.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.8/292.8 kB 17.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 49.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.2/82.2 kB 7.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 5.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pandas<2.2.2dev0,>=2.0, but you have pandas 1.5.3 which is incompatible.
# google-colab 1.0.0 requires pandas==2.0.3, but you have pandas 1.5.3 which is incompatible.
# plotnine 0.12.4 requires statsmodels>=0.14.0, but you have statsmodels 0.13.5 which is incompatible.

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/aiedu-courses/stepik_applied_tasks/main/datasets/DailyDelhiClimateTrain.csv')

df = df[['date','meantemp']]

# %% [markdown]
# Приведем данные к формату, с которым работает ETNA:
#
# * колонка `timestamp` - время в формате datetime
# * колонка `target` - целевая переменная (прогнозируемый ряд)
# * колонка `segment` - `main` в случае, если целевая переменная - это один ряд

# %%
df["timestamp"] = pd.to_datetime(df["date"])
df["target"] = df["meantemp"]
df.drop(columns=["date", "meantemp"], inplace=True)
df["segment"] = "main"

df.head()
# Out:
#    timestamp     target segment
# 0 2013-01-01  10.000000    main
# 1 2013-01-02   7.400000    main
# 2 2013-01-03   7.166667    main
# 3 2013-01-04   8.666667    main
# 4 2013-01-05   6.000000    main

# %% [markdown]
# В ETNA есть специальный класс для работы с временными рядами - TSDataset, приведем наши данные к этому формату.

# %%
from etna.datasets.tsdataset import TSDataset

df = TSDataset.to_dataset(df)
df.head()
# Out:
# segment          main
# feature        target
# timestamp
# 2013-01-01  10.000000
# 2013-01-02   7.400000
# 2013-01-03   7.166667
# 2013-01-04   8.666667
# 2013-01-05   6.000000

# %% [markdown]
# Укажем временной шаг (дни).

# %%
ts = TSDataset(df, freq="D")

ts.head()
# Out:
# segment          main
# feature        target
# timestamp
# 2013-01-01  10.000000
# 2013-01-02   7.400000
# 2013-01-03   7.166667
# 2013-01-04   8.666667
# 2013-01-05   6.000000

# %%
ts.info()
# Out:
# <class 'etna.datasets.TSDataset'>
# num_segments: 1
# num_exogs: 0
# num_regressors: 0
# num_known_future: 0
# freq: D
#          start_timestamp end_timestamp  length  num_missing
# segments
# main          2013-01-01    2016-12-31    1461            0

# %%
ts.describe()
# Out:
#          start_timestamp end_timestamp  length  num_missing  num_segments  \
# segments
# main          2013-01-01    2016-12-31    1461            0             1
#
#           num_exogs  num_regressors  num_known_future freq
# segments
# main              0               0                 0    D

# %%
ts.plot()

# %% [markdown]
# Разбиваем данные на тренировочную и тестовую части

# %%
train_ts, test_ts = ts.train_test_split(
    train_start="2013-01-01",
    train_end="2015-12-31",
    test_start="2016-01-01",
    test_end="2016-12-31",
)

# %% [markdown]
# В библиотеке ETNA реализовано множество самых разных моделей - от классической SARIMAX до нейронных сетей.
#
# Обучим самую простую модель из ETNA - NaiveModel.
#
# Наивная модель предсказывает текущее значение, равное значению ряда несколько периодов назад (lag):
#
# $$y_t = y_{t-lag}$$

# %%
HORIZON = 366 # горизонт прогнозирования

from etna.models import NaiveModel, CatBoostMultiSegmentModel, LinearPerSegmentModel, SARIMAXModel

# Fit the model
model1 = NaiveModel(lag=5)

model1.fit(train_ts)

# Make the forecast
future_ts = train_ts.make_future(future_steps=HORIZON, tail_steps=model1.context_size)

forecast_ts = model1.forecast(future_ts, prediction_size=HORIZON)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-29-8c33f2729dcb> in <cell line: 3>()
#       1 HORIZON = 366 # горизонт прогнозирования
#       2
# ----> 3 from etna.models import NaiveModel, CatBoostMultiSegmentModel, LinearPerSegmentModel, SARIMAXModel
#       4
#       5 # Fit the model
#
# /usr/local/lib/python3.10/dist-packages/etna/models/__init__.py in <module>
#      29
#      30 from etna import SETTINGS
# ---> 31 from etna.models.autoarima import AutoARIMAModel
#      32 from etna.models.base import BaseAdapter
#      33 from etna.models.base import ContextIgnorantModelType
#
# /usr/local/lib/python3.10/dist-packages/etna/models/autoarima.py in <module>
#       2
#       3 import pandas as pd
# ----> 4 import pmdarima as pm
#       5 from statsmodels.tools.sm_exceptions import ValueWarning
#       6 from statsmodels.tsa.statespace.sarimax import SARIMAXResultsWrapper
#
# /usr/local/lib/python3.10/dist-packages/pmdarima/__init__.py in <module>
#      50
#      51     # Stuff we want at top-level
# ---> 52     from .arima import auto_arima, ARIMA, AutoARIMA, StepwiseContext, decompose
#      53     from .utils import acf, autocorr_plot, c, pacf, plot_acf, plot_pacf, \
#      54         tsdisplay
#
# /usr/local/lib/python3.10/dist-packages/pmdarima/arima/__init__.py in <module>
#       3 # Author: Taylor Smith <taylor.smith@alkaline-ml.com>
#       4
# ----> 5 from .approx import *
#       6 from .arima import *
#       7 from .auto import *
#
# /usr/local/lib/python3.10/dist-packages/pmdarima/arima/approx.py in <module>
#       7 import numpy as np
#       8
# ----> 9 from ..utils.array import c, check_endog
#      10 from ..utils import get_callable
#      11 from ..compat.numpy import DTYPE
#
# /usr/local/lib/python3.10/dist-packages/pmdarima/utils/__init__.py in <module>
#       5 from .array import *
#       6 from .metaestimators import *
# ----> 7 from .visualization import *
#       8 from .wrapped import *
#       9
#
# /usr/local/lib/python3.10/dist-packages/pmdarima/utils/visualization.py in <module>
#       9 from ..compat.matplotlib import get_compatible_pyplot
#      10
# ---> 11 from statsmodels.graphics import tsaplots
#      12
#      13 import numpy as np
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/graphics/tsaplots.py in <module>
#       9
#      10 from statsmodels.graphics import utils
# ---> 11 from statsmodels.tsa.stattools import acf, pacf
#      12
#      13
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/stattools.py in <module>
#       6 from statsmodels.compat.numpy import lstsq
#       7 from statsmodels.compat.pandas import deprecate_kwarg
# ----> 8 from statsmodels.compat.python import lzip, Literal
#       9 from statsmodels.compat.scipy import _next_regular
#      10
#
# ImportError: cannot import name 'Literal' from 'statsmodels.compat.python' (/usr/local/lib/python3.10/dist-packages/statsmodels/compat/python.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from etna.metrics import SMAPE

smape = SMAPE()
smape(y_true=test_ts, y_pred=forecast_ts)
# Out:
# {'main': 50.067909843390055}

# %%
from etna.analysis import plot_forecast

plot_forecast(forecast_ts, test_ts, train_ts, n_train_samples=10)

# %% [markdown]
# ### Prophet (от Facebook)
#
# Библиотека Prophet использует аддитивную модель для прогнозирования временных рядов. Аддитивная модель предполагает, что значение временного ряда можно разложить на несколько компонент, таких как тренд, сезонность, праздничные эффекты и остатки.
#
# Модель Prophet выражается следующим уравнением:
#
# $$y_t = g_t + s_t + h_t + e_t,$$
#
# где:
#
# * $g_t$ представляет тренд, моделирующий нелинейное изменение значения временного ряда во времени
#
# * $s_t$ представляет сезонность, учитывающую повторяющиеся паттерны или циклы во временном ряду
#
# * $h_t$ представляет праздничные эффекты, учитывающие влияние праздников и событий на временной ряд
#
# * $e_t$ представляет остатки, которые предполагаются нормально распределенными шумами вокруг модели
#
# Тренд моделируется с использованием гибкой линейной модели, которая может аппроксимировать нелинейные изменения во временном ряду. Сезонность моделируется с помощью фурье-рядов, позволяющих учесть сезонные колебания с различными периодами. Праздничные эффекты моделируются путем добавления индикаторов праздников в модель.
#
# Prophet также автоматически настраивает гиперпараметры модели, такие как гибкость тренда и сезонности, а также влияние праздников. Он также предоставляет возможность пользователю настраивать некоторые параметры, такие как сезонность, шум и другие.

# %%
from etna.models import ProphetModel

model2 = ProphetModel()

model2.fit(train_ts)

# Make the forecast
future_ts = train_ts.make_future(HORIZON)
forecast_ts = model2.forecast(future_ts)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5u7sw88s/5pv24khu.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp5u7sw88s/bj8c8v23.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=58005', 'data', 'file=/tmp/tmp5u7sw88s/5pv24khu.json', 'init=/tmp/tmp5u7sw88s/bj8c8v23.json', 'output', 'file=/tmp/tmp5u7sw88s/prophet_model1kljocnk/prophet_model-20230804162552.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 16:25:52 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:25:52 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
smape(y_true=test_ts, y_pred=forecast_ts)
# Out:
# {'main': 10.532028749602292}

# %%
plot_forecast(forecast_ts, test_ts, train_ts, n_train_samples=10)

# %% [markdown]
# # Pipeline
#
# Для обучения и валидации модели будем использовать сущность `Pipeline`. В целом, использование `Pipeline` позволит ускорить и упростить обучение и тестирование модели. Например, разбиение на тренировочные и тестовые выборки при запуске кросс валидации в таком случае будет производиться автоматически.
#
# `Pipeline` имеет несколько параметров:
#
# * `model` - модель, которая будет обучаться и тестироваться;
# * `horizon` - горизонт прогнозирования;
# * `transforms` - список преобразований, которые нужно применить к данным.
#
# Ещё одним достоинством использования пайплайна является автоматическое прямое и обратное преобразование данных, следовательно, о согласованности данных можно не беспокоиться. Кросс валидацию на исторических данных можно запустить с помощью метода `backtest`.

# %%
from etna.pipeline import Pipeline
from etna.metrics import MAE, SMAPE
from etna.transforms import STLTransform, LagTransform, MeanSegmentEncoderTransform

pipe = Pipeline(
    transforms=[
        STLTransform(in_column="target", period=7, model="arima"),
        LagTransform(in_column="target", lags=list(range(3, 10, 1))),
    ],
    model=LinearPerSegmentModel(),
    horizon=3
)

# %% [markdown]
# ## Backtest
#
# Backtest - это кросс-валидация на временных рядах.

# %%
metrics, forecast, _ = pipe.backtest(
    ts=ts, metrics=[MAE(), SMAPE()], n_folds=5)

metrics
# Out:
# [Parallel(n_jobs=1)]: Done   1 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done   2 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=1)]: Done   3 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=1)]: Done   4 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=1)]: Done   5 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=1)]: Done   5 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=1)]: Done   1 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done   2 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done   3 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done   4 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=1)]: Done   5 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=1)]: Done   5 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=1)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done   2 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done   3 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done   4 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done   5 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done   5 tasks      | elapsed:    0.1s
#   segment       MAE      SMAPE  fold_number
# 0    main  0.956865   5.492141            0
# 0    main  1.679161   9.454322            1
# 0    main  1.986150  12.403313            2
# 0    main  0.500228   2.888707            3
# 0    main  0.352171   2.309867            4

# %%
mae_value = metrics.mean().to_dict()["MAE"]

mae_value
# Out:
# 1.094914868018162

# %%
from etna.analysis import plot_backtest

plot_backtest(forecast_df=forecast, ts=ts, history_len=5)

# %%
pipe2 = Pipeline(
    transforms=[
        STLTransform(in_column="target", period=7, model="arima"),
        LagTransform(in_column="target", lags=list(range(3, 10, 1))),
    ],
    model=CatBoostMultiSegmentModel(n_estimators=1000, learning_rate=0.01),
    horizon=3
)

# %%
metrics, forecast, _ = pipe2.backtest(
    ts=ts, metrics=[MAE(), SMAPE()], n_folds=5)

metrics
# Out:
# [Parallel(n_jobs=1)]: Done   1 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=1)]: Done   2 tasks      | elapsed:    4.8s
# [Parallel(n_jobs=1)]: Done   3 tasks      | elapsed:    6.4s
# [Parallel(n_jobs=1)]: Done   4 tasks      | elapsed:    8.0s
# [Parallel(n_jobs=1)]: Done   5 tasks      | elapsed:    9.6s
# [Parallel(n_jobs=1)]: Done   5 tasks      | elapsed:    9.6s
# [Parallel(n_jobs=1)]: Done   1 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done   2 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done   3 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done   4 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done   5 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=1)]: Done   5 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=1)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done   2 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done   3 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done   4 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done   5 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done   5 tasks      | elapsed:    0.1s
#   segment       MAE      SMAPE  fold_number
# 0    main  0.606679   3.509500            0
# 0    main  1.688889   9.534459            1
# 0    main  2.000959  12.491365            2
# 0    main  0.399407   2.309858            3
# 0    main  0.238378   1.558969            4

# %%
mae_value = metrics.mean().to_dict()["MAE"]

mae_value
# Out:
# 0.9868626308337773

# %%
plot_backtest(forecast_df=forecast, ts=ts, history_len=5)

# %% [markdown]
# Примеры ноутбуков с использованием ETNA:
#
# * [tutorial из документации](https://github.com/tinkoff-ai/etna/blob/master/examples/get_started.ipynb)
#
# * [семинар с курса "Прикладные задачи машинного обучения" в ВШЭ](https://github.com/hse-ds/iad-applied-ds/blob/master/2023/seminars/sem07_ts2/sem07_ts2.ipynb)

# %% [markdown]
# ## Учет экзогенных факторов

# %%
df = pd.read_csv('https://raw.githubusercontent.com/aiedu-courses/stepik_applied_tasks/main/datasets/DailyDelhiClimateTrain.csv')

df['date'] = pd.to_datetime(df['date'], format = '%Y-%m-%d')

df.head()
# Out:
#         date   meantemp   humidity  wind_speed  meanpressure
# 0 2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 1 2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2 2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 3 2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 4 2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %%
df = df[['date','meantemp','meanpressure']].set_index('date')

# %%
def preprocess_data_exog(data, lag_start=5, lag_end=20, test_size=0.15):

    exog = "meanpressure"

    data = pd.DataFrame(data.copy())

    # считаем индекс в датафрейме, после которого начинается тестовый отрезок
    test_index = int(len(data) * (1 - test_size))

    # добавляем лаги исходного ряда в качестве признаков
    for i in range(lag_start, lag_end):
        data[f"lag_{i}"] = data.meantemp.shift(i)
        data[f"lag_exog_{i}"] = data[exog].shift(i)

    data["weekday"] = data.index.weekday
    data["week"] = data.index.week
    data["month"] = data.index.month
    data["year"] = data.index.year

    # считаем средние только по тренировочной части, чтобы избежать лика (data leak)
    data["weekday_average"] = list(map(code_mean(data[:test_index], "weekday", "meantemp").get, data.weekday))
    data["week_average"] = list(map(code_mean(data[:test_index], "week", "meantemp").get, data.week))
    data["month_average"] = list(map(code_mean(data[:test_index], "month", "meantemp").get, data.month))
    data["year_average"] = list(map(code_mean(data[:test_index], "year", "meantemp").get, data.year))

    data["weekday_average_exog"] = list(map(code_mean(data[:test_index], "weekday", exog).get, data.weekday))
    data["week_average_exog"] = list(map(code_mean(data[:test_index], "week", exog).get, data.week))
    data["month_average_exog"] = list(map(code_mean(data[:test_index], "month", exog).get, data.month))
    data["year_average_exog"] = list(map(code_mean(data[:test_index], "year", exog).get, data.year))

    # выкидываем закодированные средними признаки
    data.drop(["weekday", "week", "month", "year", exog], axis=1, inplace=True)

    data = data.dropna()
    data = data.reset_index(drop=True)

    # разбиваем весь датасет на тренировочную и тестовую выборку
    X_train = data.loc[:test_index].drop(["meantemp"], axis=1)
    y_train = data.loc[:test_index]["meantemp"]
    X_test = data.loc[test_index:].drop(["meantemp"], axis=1)
    y_test = data.loc[test_index:]["meantemp"]

    return X_train, X_test, y_train, y_test

# %%
X_train_big, X_test_big, y_train, y_test = preprocess_data_exog(df, test_size=0.3, lag_start=3, lag_end=10)

X_train_big.head()
# Out:
#        lag_3   lag_exog_3      lag_4   lag_exog_4      lag_5   lag_exog_5  \
# 0   7.000000  1020.000000   7.000000  1018.000000   6.000000  1016.500000
# 1   8.857143  1018.714286   7.000000  1020.000000   7.000000  1018.000000
# 2  14.000000  1017.000000   8.857143  1018.714286   7.000000  1020.000000
# 3  11.000000  1015.666667  14.000000  1017.000000   8.857143  1018.714286
# 4  15.714286  1016.142857  11.000000  1015.666667  14.000000  1017.000000
#
#       lag_6   lag_exog_6     lag_7   lag_exog_7  ...      lag_9   lag_exog_9  \
# 0  8.666667  1017.166667  7.166667  1018.666667  ...  10.000000  1015.666667
# 1  6.000000  1016.500000  8.666667  1017.166667  ...   7.400000  1017.800000
# 2  7.000000  1018.000000  6.000000  1016.500000  ...   7.166667  1018.666667
# 3  7.000000  1020.000000  7.000000  1018.000000  ...   8.666667  1017.166667
# 4  8.857143  1018.714286  7.000000  1020.000000  ...   6.000000  1016.500000
#
#    weekday_average  week_average  month_average  year_average  \
# 0        25.440460     11.925454      12.738377     24.791494
# 1        25.372054     11.925454      12.738377     24.791494
# 2        25.331414     11.925454      12.738377     24.791494
# 3        25.202210     11.925454      12.738377     24.791494
# 4        25.499234     13.067177      12.738377     24.791494
#
#    weekday_average_exog  week_average_exog  month_average_exog  \
# 0           1007.715550        1017.573980         1018.552483
# 1           1007.542990        1017.573980         1018.552483
# 2           1007.585645        1017.573980         1018.552483
# 3           1007.803264        1017.573980         1018.552483
# 4           1007.899013        1018.442744         1018.552483
#
#    year_average_exog
# 0        1007.642172
# 1        1007.642172
# 2        1007.642172
# 3        1007.642172
# 4        1007.642172
#
# [5 rows x 22 columns]

# %% [markdown]
# Заново обучим линейную регрессию на исходных данных (чтобы затем сравнить)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
preds = lr.predict(X_test)

plt.figure(figsize=(10, 5))
plt.plot(preds, "r", label="prediction")
plt.plot(y_test.values, label="actual")
plt.grid(True)
plt.legend(loc="best")
plt.title(f"Linear regression\n Mean absolute error {mean_absolute_error(preds, y_test)} degrees");

# %% [markdown]
# Теперь обучим модель на данных с учетом экзогенных факторов

# %%
lr = LinearRegression()
lr.fit(X_train_big, y_train)
preds = lr.predict(X_test_big)

plt.figure(figsize=(10, 5))
plt.plot(preds, "r", label="prediction")
plt.plot(y_test.values, label="actual")
plt.grid(True)
plt.legend(loc="best")
plt.title(f"Linear regression\n Mean absolute error {mean_absolute_error(preds, y_test)} degrees");

# %%
coef_table = pd.DataFrame({'features' : list(X_train_big.columns), 'weights' : lr.coef_})

coef_table.sort_values(by='weights')

# %% [markdown]
# # Курсы сообщества AI Education

# %% [markdown]
# ### Интенсивы

# %% [markdown]
# [Линейные модели и их презентация](https://stepik.org/a/177215)  (**с 9 августа**)
#
# В курсе вы не только разберете теоретическую сторону предмета, но и узнаете как использовать модели на практике:
#   * Будете оценивать качество моделей регрессии и классификации
#   * Проходить все этапы задачи ML: от разведочного анализа до получения прогноза и его интерпретации
#   * Cтроить интерактивные дашборды при помощи библиотеки Streamlit
#   * Cоздавать веб-сервисы с использованием фреймворка FastApi
#
#
# **Программа**
# *   Задача регрессии. Линейная регрессия
# *   ООП в Python (классы, наследование, декораторы)
# *   Асинхронный Python
# *   Метрики качества регрессии и интерпретация моделей
# *   SQL (PostgreSQL)
# *   Работа с SQLAlchemy в Python
# *   Линейная классификация. Логистическая регрессия
# *   Основы работы с FastApi
# *   Интерпретация моделей классификации
# *   Фреймоворк Streamlit
# *   Подведение итогов

# %% [markdown]
# [Разведочный анализ данных](https://stepik.org/a/177213) (**в записи**)
#
# На интенсиве вы познакомитесь с основными и продвинутыми подходами анализа данных:
#   * Научитесь исследовать данные при помощи современных библиотек (NumPy, Pandas, Polars, Matplotlib, Seaborn)
#   * Обучите свою первую модель машинного обучения
#   * Построите интерактивный дашборд при помощи инструмента ExplainerDashboard
#   * Начнете использовать такие инструменты разработчика как Git и Docker

# %% [markdown]
# В каждом интенсиве по 11 вебинаров (4 по анализу данных / 6 по разработке / финальный с подведением итогов).

# %% [markdown]
# ### Курсы

# %% [markdown]
# [Практический Machine Learning](https://stepik.org/a/125501)
#
#   * Курс посвящен изучению всех основных задач и подходов в машинном обучении. Курс дает как теорию методов, так и обширную практику.
#   * За 16 недель курса вы пройдете путь практически с нуля в машинном обучении до уверенного владения основными алгоритмами и подходами.
#
# [Прикладные задачи машинного обучения](https://stepik.org/a/175967)
#
# * В курсе подробно разобраны следующие темы:
#
#   * построение рекомендательных систем
#   * анализ временных рядов
#   * продвинутые методы интерпретации ML-моделей
#   * AutoML
#
# * Курс находится в процессе наполнения, в нем будут появляться новые актуальные и прикладные в ML-темы.
